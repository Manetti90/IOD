# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %% [markdown]
# # Lab 8.2: Working with Text
# - Using [NLTK](http://www.nltk.org) (Natural Language Toolkit)
# - Using [spaCy](https://spacy.io)
#
# INSTRUCTIONS:
# - Run the cells
# - Observe and understand the results
# - Answer the questions

# %% [markdown]
# ## Import libraries

# %%
## Import Libraries
# %matplotlib inline
import matplotlib.pyplot as plt
from collections import Counter

# !pip install regex
# !pip install spacy
import regex as re
import spacy
# !pip install nltk
import nltk
# Out:
# Requirement already satisfied: regex in c:\users\matth\anaconda3\envs\py312\lib\site-packages (2024.11.6)
# Requirement already satisfied: spacy in c:\users\matth\anaconda3\envs\py312\lib\site-packages (3.8.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (3.0.10)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (0.16.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.2.3)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (2.11.7)
# Requirement already satisfied: jinja2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (3.1.5)
# Requirement already satisfied: setuptools in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (75.8.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.1)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.15.1)
# Requirement already satisfied: wrapt in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.0)
# Collecting nltk
#   Downloading nltk-3.9.1-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: click in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from nltk) (8.1.7)
# Collecting joblib (from nltk)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from nltk) (2024.11.6)
# Requirement already satisfied: tqdm in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: colorama in c:\users\matth\anaconda3\envs\py312\lib\site-packages (from click->nltk) (0.4.6)
# Downloading nltk-3.9.1-py3-none-any.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 26.5 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Installing collected packages: joblib, nltk
# Successfully installed joblib-1.5.1 nltk-3.9.1

# %% [markdown]
# ## Load data

# %%
## Loading the data

input_file = 'ncc-1701-D.txt'

with open(input_file, 'r') as f:
    text = f.read()

# %% [markdown]
# ## Inspect the data

# %%
print(text[:1000])
# Out:
# USS Enterprise (NCC-1701-D)
#
# "For five hundred years, every ship that has borne the name of the Enterprise has become a legend. This one is no different."
#
# The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise. During her career, the Enterprise served as the Federation flagship. The Enterprise was destroyed during the Battle of Veridian III in 2371.
#
# ==History==
# ===Construction and launch===
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system. The construction was a massive undertaking, involving thousands of people across disciplines. Construction was supervised by Commander Orfil Quinteros. Dr. Leah Brahms was responsible for much of the Enterprise's warp propulsion system design. Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus.
#
# One of the ship's nacelle tube was

# %% [markdown]
# ## Work the data
# - if necessary or desired
#     - remove text or content, e.g. quotes (") or metadata (===)
#     - add content or markers, e.g. (#FLAG, --NAME--)
#     - remove or convert special symbols, e.g. "é" to "e"
#     - remove or convert emoticons

# %%
# ANSWER
text = re.sub(r'[="]', '', text)
print(text[:1000])
# Out:
# USS Enterprise (NCC-1701-D)
#
# For five hundred years, every ship that has borne the name of the Enterprise has become a legend. This one is no different.
#
# The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise. During her career, the Enterprise served as the Federation flagship. The Enterprise was destroyed during the Battle of Veridian III in 2371.
#
# History
# Construction and launch
# The Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system. The construction was a massive undertaking, involving thousands of people across disciplines. Construction was supervised by Commander Orfil Quinteros. Dr. Leah Brahms was responsible for much of the Enterprise's warp propulsion system design. Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus.
#
# One of the ship's nacelle tube was the site of

# %% [markdown]
# ## Helper method

# %%
# create a bar chart of the frequency of the words in the text
def plot_words(tokens, top = 30):
    tokens_counter = Counter(tokens)
    tok = [t for (t, _) in tokens_counter.most_common()]
    val = [v for (_, v) in tokens_counter.most_common()]

    plt.figure(figsize = (16, 6))
    plt.bar(tok[:top], val[:top])
    plt.title('Number of terms: %d' % len(tokens_counter))
    plt.xticks(rotation = 90)

    for i, label in enumerate(val[:top]):
        plt.text(i, label, label, ha='center', va='bottom')

    plt.show()

# %% [markdown]
# ## spaCy model invocation and text processing
# spaCy does the processing of the text as part of the reading of the data.

# %%
# load spaCy and the English model
# !python -m spacy download en_core_web_sm
nlp = spacy.load('en_core_web_sm')


# process the text
doc = nlp(text)
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------- -------------------------- 4.2/12.8 MB 22.9 MB/s eta 0:00:01
#      ------------------------------ --------- 9.7/12.8 MB 25.2 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 25.1 MB/s eta 0:00:00
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.8.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %% [markdown]
# ## Tokenise

# %%
# only show the results
# spaCy has done it already
for i, t in enumerate(doc):
    print('%2d| %r' % (i+1, t.text))
    if t.text == '.':
        break
# Out:
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701'
#  5| '-'
#  6| 'D'
#  7| ')'
#  8| '\n\n'
#  9| 'For'
# 10| 'five'
# 11| 'hundred'
# 12| 'years'
# 13| ','
# 14| 'every'
# 15| 'ship'
# 16| 'that'
# 17| 'has'
# 18| 'borne'
# 19| 'the'
# 20| 'name'
# 21| 'of'
# 22| 'the'
# 23| 'Enterprise'
# 24| 'has'
# 25| 'become'
# 26| 'a'
# 27| 'legend'
# 28| '.'

# %%
# ANSWER
plot_words(['%r' % t.text for t in doc])

# %% [markdown]
# ### Stop Words

# %%
## spaCy
print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
for i, t in enumerate(doc):
    print('%2d| %-15r %r' % (i+1, t.text, ('' if t.is_stop else t.text)))

    # break after the first sentence
    if t.text == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'           'USS'
#  2| 'Enterprise'    'Enterprise'
#  3| '('             '('
#  4| 'NCC-1701'      'NCC-1701'
#  5| '-'             '-'
#  6| 'D'             'D'
#  7| ')'             ')'
#  8| '\n\n'          '\n\n'
#  9| 'For'           ''
# 10| 'five'          ''
# 11| 'hundred'       ''
# 12| 'years'         'years'
# 13| ','             ','
# 14| 'every'         ''
# 15| 'ship'          'ship'
# 16| 'that'          ''
# 17| 'has'           ''
# 18| 'borne'         'borne'
# 19| 'the'           ''
# 20| 'name'          ''
# 21| 'of'            ''
# 22| 'the'           ''
# 23| 'Enterprise'    'Enterprise'
# 24| 'has'           ''
# 25| 'become'        ''
# 26| 'a'             ''
# 27| 'legend'        'legend'
# 28| '.'             '.'

# %%
plot_words(['%r' % t.text for t in doc if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Check Part of Speech

# %%
## spaCy
for i, t in enumerate(doc):
    print('%2d|%-12r : %-5s %s' % (i+1, t.text, t.pos_, t.tag_))
    if t.text == '.':
        break
# Out:
#  1|'USS'        : PROPN NNP
#  2|'Enterprise' : PROPN NNP
#  3|'('          : PUNCT -LRB-
#  4|'NCC-1701'   : PROPN NNP
#  5|'-'          : PUNCT HYPH
#  6|'D'          : NOUN  NN
#  7|')'          : PUNCT -RRB-
#  8|'\n\n'       : SPACE _SP
#  9|'For'        : ADP   IN
# 10|'five'       : NUM   CD
# 11|'hundred'    : NUM   CD
# 12|'years'      : NOUN  NNS
# 13|','          : PUNCT ,
# 14|'every'      : DET   DT
# 15|'ship'       : NOUN  NN
# 16|'that'       : PRON  WDT
# 17|'has'        : AUX   VBZ
# 18|'borne'      : VERB  VBN
# 19|'the'        : DET   DT
# 20|'name'       : NOUN  NN
# 21|'of'         : ADP   IN
# 22|'the'        : DET   DT
# 23|'Enterprise' : NOUN  NN
# 24|'has'        : AUX   VBZ
# 25|'become'     : VERB  VBN
# 26|'a'          : DET   DT
# 27|'legend'     : NOUN  NN
# 28|'.'          : PUNCT .

# %% [markdown]
# ### Lemmatisation

# %%
## spaCy
print('i | Token        Lemma')
print('--| ------------ ------------')
for i, t in enumerate(doc):
    print('%2d| %-12r %r' % (i+1, t.text, t.lemma_))
    if t.text == '.':
        break
# Out:
# i | Token        Lemma
# --| ------------ ------------
#  1| 'USS'        'USS'
#  2| 'Enterprise' 'Enterprise'
#  3| '('          '('
#  4| 'NCC-1701'   'NCC-1701'
#  5| '-'          '-'
#  6| 'D'          'd'
#  7| ')'          ')'
#  8| '\n\n'       '\n\n'
#  9| 'For'        'for'
# 10| 'five'       'five'
# 11| 'hundred'    'hundred'
# 12| 'years'      'year'
# 13| ','          ','
# 14| 'every'      'every'
# 15| 'ship'       'ship'
# 16| 'that'       'that'
# 17| 'has'        'have'
# 18| 'borne'      'bear'
# 19| 'the'        'the'
# 20| 'name'       'name'
# 21| 'of'         'of'
# 22| 'the'        'the'
# 23| 'Enterprise' 'enterprise'
# 24| 'has'        'have'
# 25| 'become'     'become'
# 26| 'a'          'a'
# 27| 'legend'     'legend'
# 28| '.'          '.'

# %%
plot_words(['%r' % t.lemma_ for t in doc if not (t.is_stop | t.is_punct)])

# %% [markdown]
# ### Entity Recognition

# %%
## spaCy
for i, s in enumerate(doc.sents):
    print('%2d: %s' % (i, re.sub(r'\n+', '', s.text)))
    if s.as_doc().ents:
        print('-'*80)
        for e in s.as_doc().ents:
            print('%-11s: %s' % (e.label_, re.sub(r'\n+', '', e.text)))
    print('='*80)
# Out:
#  0: USS Enterprise (NCC-1701-D)
# --------------------------------------------------------------------------------
# ORG        : USS Enterprise
# ================================================================================
#  1: For five hundred years, every ship that has borne the name of the Enterprise has become a legend.
# --------------------------------------------------------------------------------
# DATE       : five hundred years
# ORG        : Enterprise
# ================================================================================
#  2: This one is no different.
# ================================================================================
#  3: The USS Enterprise (NCC-1701-D) was a 24th century United Federation of Planets Galaxy Class starship operated by Starfleet, and the fifth Federation ship to bear the name Enterprise.
# --------------------------------------------------------------------------------
# ORG        : The USS Enterprise
# DATE       : a 24th century
# ORG        : United Federation of Planets Galaxy
# ORDINAL    : fifth
# ================================================================================
#  4: During her career, the Enterprise served as the Federation flagship.
# --------------------------------------------------------------------------------
# ORG        : Enterprise
# ORG        : Federation
# ================================================================================
#  5: The Enterprise was destroyed during the Battle of Veridian III in 2371.
# --------------------------------------------------------------------------------
# EVENT      : the Battle of Veridian III
# DATE       : 2371
# ================================================================================
#  6: HistoryConstruction and launchThe Enterprise was built at Utopia Planitia Fleet Yards orbiting Mars in the Solar system.
# --------------------------------------------------------------------------------
# LOC        : Mars
# ORG        : Solar
# ================================================================================
#  7: The construction was a massive undertaking, involving thousands of people across disciplines.
# --------------------------------------------------------------------------------
# CARDINAL   : thousands
# ================================================================================
#  8: Construction was supervised by Commander Orfil Quinteros.
# --------------------------------------------------------------------------------
# PERSON     : Orfil Quinteros
# ================================================================================
#  9: Dr. Leah Brahms was responsible for much of the Enterprise's warp propulsion system design.
# --------------------------------------------------------------------------------
# PERSON     : Leah Brahms
# ORG        : Enterprise
# ================================================================================
# 10: Some of the Enterprise's components were derived from technology originally developed on the USS Pegasus.
# --------------------------------------------------------------------------------
# PRODUCT    : the USS Pegasus
# ================================================================================
# 11: One of the ship's nacelle tube was the site of a multiple murder-suicide while she was still under construction at Utopia Planitia.
# --------------------------------------------------------------------------------
# CARDINAL   : One
# PERSON     : nacelle tube
# PERSON     : Planitia
# ================================================================================
# 12: A member of the construction team, Walter Pierce, became jealous of a former lover's new relationship.
# --------------------------------------------------------------------------------
# PERSON     : Walter Pierce
# ================================================================================
# 13: He killed the two officers, Marla Finn and William Hodges, then disposed of their bodies in the plasma stream.
# --------------------------------------------------------------------------------
# CARDINAL   : two
# PERSON     : Marla Finn
# PERSON     : William Hodges
# ================================================================================
# 14: Pierce committed suicide in the same manner, leaving a telepathic imprint in a bulkhead that was not discovered until 2370.
# --------------------------------------------------------------------------------
# DATE       : 2370
# ================================================================================
# 15: On stardate 40759.5, in the year 2363, the Enterprise was launched from Mars.
# --------------------------------------------------------------------------------
# CARDINAL   : 40759.5
# DATE       : the year 2363
# ORG        : Enterprise
# LOC        : Mars
# ================================================================================
# 16: On stardate 41025.5, the Enterprise was commissioned.
# --------------------------------------------------------------------------------
# CARDINAL   : 41025.5
# ORG        : Enterprise
# ================================================================================
# 17: These stardates weren't mentioned in dialog; they were from the Enterprise dedication plaque.
# --------------------------------------------------------------------------------
# ORG        : Enterprise
# ================================================================================
# 18: Final systems completion and shakedown was conducted at Earth Station McKinley.
# --------------------------------------------------------------------------------
# FAC        : Earth Station McKinley
# ================================================================================
# 19: Captain Jean-Luc Picard took command of the ship on stardate 41148 at the order of Rear Admiral Norah Satie.
# --------------------------------------------------------------------------------
# PERSON     : Jean-Luc Picard
# DATE       : 41148
# ORG        : Rear Admiral
# PERSON     : Norah Satie
# ================================================================================
# 20: LegacyCommander Riker was upset over the loss of the Enterprise.
# --------------------------------------------------------------------------------
# PERSON     : Riker
# ================================================================================
# 21: Having hoped he would one day command the ship, he was disappointed that he never got that opportunity.
# --------------------------------------------------------------------------------
# DATE       : one day
# ================================================================================
# 22: However, Picard expressed doubt that the Enterprise-D would be the last vessel to carry the name.
# --------------------------------------------------------------------------------
# PERSON     : Picard
# ================================================================================
# 23: The Enterprise was so dear to Worf that, shortly after being reassigned to Deep Space 9 in 2372, he briefly considered resigning from Starfleet.
# --------------------------------------------------------------------------------
# PERSON     : Worf
# WORK_OF_ART: Deep Space 9
# DATE       : 2372
# GPE        : Starfleet
# ================================================================================
# 24: Station commander Captain Benjamin Sisko expressed regret on the loss of the Enterprise and offered his condolences over the destruction of the ship to Worf, saying the Enterprise was a good ship.
# --------------------------------------------------------------------------------
# PERSON     : Benjamin Sisko
# ORG        : Enterprise
# PERSON     : Worf
# ================================================================================
# 25: Captain Picard's belief that the Enterprise-D would not be the final ship to bear the name was borne out with the christening of the Class Sovereign USS Enterprise NCC-1701-E, later the same year.
# --------------------------------------------------------------------------------
# PERSON     : Picard
# DATE       : later the same year
# ================================================================================
# 26: In that instance, the legacy of the Enterprise continued with Picard reprising his role as CO and selecting most of the former crew from the Enterprise-D, with the notable exception of Worf due to his most recent assignment to DS9 (though he temporarily joined the Enterprise-E crew on several of their more notable missions).
# --------------------------------------------------------------------------------
# ORG        : Enterprise
# PERSON     : Picard
# ORG        : CO
# PERSON     : Worf
# ================================================================================

# %% [markdown]
# ## Extra: Using NLTK for NLP
#
# ### Tokenise

# %%
# use nltk to find tokens
import nltk
nltk.download('punkt_tab')
tokens = nltk.word_tokenize(text)

for i, t in enumerate(tokens[:25]):
    print('%2d| %r' % (i+1, t))
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...
#  1| 'USS'
#  2| 'Enterprise'
#  3| '('
#  4| 'NCC-1701-D'
#  5| ')'
#  6| 'For'
#  7| 'five'
#  8| 'hundred'
#  9| 'years'
# 10| ','
# 11| 'every'
# 12| 'ship'
# 13| 'that'
# 14| 'has'
# 15| 'borne'
# 16| 'the'
# 17| 'name'
# 18| 'of'
# 19| 'the'
# 20| 'Enterprise'
# 21| 'has'
# 22| 'become'
# 23| 'a'
# 24| 'legend'
# 25| '.'
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.

# %%
plot_words(tokens)

# %% [markdown]
# ### Stop words

# %%
nltk.download('stopwords')
stopWords = nltk.corpus.stopwords.words('english')

stopWords.sort()
print(', '.join(stopWords))
# Out:
# a, about, above, after, again, against, ain, all, am, an, and, any, are, aren, aren't, as, at, be, because, been, before, being, below, between, both, but, by, can, couldn, couldn't, d, did, didn, didn't, do, does, doesn, doesn't, doing, don, don't, down, during, each, few, for, from, further, had, hadn, hadn't, has, hasn, hasn't, have, haven, haven't, having, he, he'd, he'll, he's, her, here, hers, herself, him, himself, his, how, i, i'd, i'll, i'm, i've, if, in, into, is, isn, isn't, it, it'd, it'll, it's, its, itself, just, ll, m, ma, me, mightn, mightn't, more, most, mustn, mustn't, my, myself, needn, needn't, no, nor, not, now, o, of, off, on, once, only, or, other, our, ours, ourselves, out, over, own, re, s, same, shan, shan't, she, she'd, she'll, she's, should, should've, shouldn, shouldn't, so, some, such, t, than, that, that'll, the, their, theirs, them, themselves, then, there, these, they, they'd, they'll, they're, they've, this, those, through, to, too, under, until, up, ve, very, was, wasn, wasn't, we, we'd, we'll, we're, we've, were, weren, weren't, what, when, where, which, while, who, whom, why, will, with, won, won't, wouldn, wouldn't, y, you, you'd, you'll, you're, you've, your, yours, yourself, yourselves
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.

# %%
# ANSWER
# NOTE: see the `.lower()` method applied to token
tokens_no_stop = [t for t in tokens if t.lower() not in stopWords]

# %%
## NLTK
i = 0
j = 0

print('i | with stop words without')
print('--| --------------- ------------')

# for all the tokens
while i < len(tokens):
    # same word
    if tokens[i] == tokens_no_stop[j]:
        print('%2d| %-15r %r' % (i+1, tokens[i], tokens_no_stop[j]))
        j += 1
    # not the same word
    else:
        print('%2d| %-15r' % (i+1, tokens[i]))

    # next word
    i += 1
    # break after the first sentence
    if tokens[i-1] == '.':
        break
# Out:
# i | with stop words without
# --| --------------- ------------
#  1| 'USS'           'USS'
#  2| 'Enterprise'    'Enterprise'
#  3| '('             '('
#  4| 'NCC-1701-D'    'NCC-1701-D'
#  5| ')'             ')'
#  6| 'For'
#  7| 'five'          'five'
#  8| 'hundred'       'hundred'
#  9| 'years'         'years'
# 10| ','             ','
# 11| 'every'         'every'
# 12| 'ship'          'ship'
# 13| 'that'
# 14| 'has'
# 15| 'borne'         'borne'
# 16| 'the'
# 17| 'name'          'name'
# 18| 'of'
# 19| 'the'
# 20| 'Enterprise'    'Enterprise'
# 21| 'has'
# 22| 'become'        'become'
# 23| 'a'
# 24| 'legend'        'legend'
# 25| '.'             '.'

# %%
# Create plot of words without stopword
# ANSWER
plot_words(tokens_no_stop)

# %% [markdown]
# ### Check Part of Speech

# %%
# define PoS
pos_list = {
    'CC':   'coordinating conjunction',
    'CD':   'cardinal digit',
    'DT':   'determiner',
    'EX':   'existential there (like: "there is" ... think of it like "there exists")',
    'FW':   'foreign word',
    'IN':   'preposition/subordinating conjunction',
    'JJ':   'adjective "big"',
    'JJR':  'adjective, comparative "bigger"',
    'JJS':  'adjective, superlative "biggest"',
    'LS':   'list marker 1)',
    'MD':   'modal could, will',
    'NN':   'noun, singular "desk"',
    'NNS':  'noun plural "desks"',
    'NNP':  'proper noun, singular "Harrison"',
    'NNPS': 'proper noun, plural "Americans"',
    'PDT':  'predeterminer "all the kids"',
    'POS':  'possessive ending parent"s',
    'PRP':  'personal pronoun I, he, she',
    'PRP$': 'possessive pronoun my, his, hers',
    'RB':   'adverb very, silently,',
    'RBR':  'adverb, comparative better',
    'RBS':  'adverb, superlative best',
    'RP':   'particle give up',
    'TO':   'to go "to" the store.',
    'UH':   'interjection errrrrrrrm',
    'VB':   'verb, base form take',
    'VBD':  'verb, past tense took',
    'VBG':  'verb, gerund/present participle taking',
    'VBN':  'verb, past participle taken',
    'VBP':  'verb, sing. present, non-3d take',
    'VBZ':  'verb, 3rd person sing. present takes',
    'WDT':  'wh-determiner which',
    'WP':   'wh-pronoun who, what',
    'WP$':  'possessive wh-pronoun whose',
    'WRB':  'wh-abverb where, when',
}

# %%
## nltk
nltk.download('averaged_perceptron_tagger_eng')
tagged = nltk.pos_tag(tokens)

for i, t in enumerate(tagged[:25]):
    print('%2d|%-12r : %-4s %s' % (i+1, t[0], t[1], (pos_list[t[1]] if t[1] in pos_list else '-')))
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.
#  1|'USS'        : NNP  proper noun, singular "Harrison"
#  2|'Enterprise' : NNP  proper noun, singular "Harrison"
#  3|'('          : (    -
#  4|'NCC-1701-D' : NNP  proper noun, singular "Harrison"
#  5|')'          : )    -
#  6|'For'        : IN   preposition/subordinating conjunction
#  7|'five'       : CD   cardinal digit
#  8|'hundred'    : CD   cardinal digit
#  9|'years'      : NNS  noun plural "desks"
# 10|','          : ,    -
# 11|'every'      : DT   determiner
# 12|'ship'       : NN   noun, singular "desk"
# 13|'that'       : WDT  wh-determiner which
# 14|'has'        : VBZ  verb, 3rd person sing. present takes
# 15|'borne'      : VBN  verb, past participle taken
# 16|'the'        : DT   determiner
# 17|'name'       : NN   noun, singular "desk"
# 18|'of'         : IN   preposition/subordinating conjunction
# 19|'the'        : DT   determiner
# 20|'Enterprise' : NNP  proper noun, singular "Harrison"
# 21|'has'        : VBZ  verb, 3rd person sing. present takes
# 22|'become'     : VBN  verb, past participle taken
# 23|'a'          : DT   determiner
# 24|'legend'     : NN   noun, singular "desk"
# 25|'.'          : .    -

# %% [markdown]
# ### Stemming

# %%
## nltk
ps = nltk.porter.PorterStemmer()
stemmed = ' '.join([ps.stem(word) for word in text.split()])

# %% [markdown]
# ### Lemmatisation

# %%
## nltk
nltk.download('wordnet')
wl = nltk.stem.WordNetLemmatizer()
lemma = ' '.join([wl.lemmatize(word) for word in text.split()])
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...

# %%
## nltk
dot = stemmed.find('.') + 1
sl = stemmed[:dot].split()
dot = lemma.find('.') + 1
ll = lemma[:dot].split()

print('i | Stem           Lemma')
print('--| -------------- ------------')
for i, p in enumerate(zip(sl, ll)):
    print('%2d| %-12r   %-12r' % (i+1, p[0], p[1]))
# Out:
# i | Stem           Lemma
# --| -------------- ------------
#  1| 'uss'          'USS'
#  2| 'enterpris'    'Enterprise'
#  3| '(ncc-1701-d)'   '(NCC-1701-D)'
#  4| 'for'          'For'
#  5| 'five'         'five'
#  6| 'hundr'        'hundred'
#  7| 'years,'       'years,'
#  8| 'everi'        'every'
#  9| 'ship'         'ship'
# 10| 'that'         'that'
# 11| 'ha'           'ha'
# 12| 'born'         'borne'
# 13| 'the'          'the'
# 14| 'name'         'name'
# 15| 'of'           'of'
# 16| 'the'          'the'
# 17| 'enterpris'    'Enterprise'
# 18| 'ha'           'ha'
# 19| 'becom'        'become'
# 20| 'a'            'a'
# 21| 'legend.'      'legend.'

# %%
plot_words(stemmed.split())

# %%
plot_words(lemma.split())

# %% [markdown]
# ### Entity recognition

# %%
## nltk
nltk.download('maxent_ne_chunker_tab')
nltk.download('words')
entities = nltk.chunk.ne_chunk(tagged)

for e in entities:
    s = re.sub(r'[\(\)]', '', str(e))
    if s.find('/NNP') > 0:
        t = s.split()[0]
        n = ' '.join([re.sub(r'/NNP', '', x) for x in s.split()[1:]])
        print('%-12s: %s' % (t, n))
# Out:
# [nltk_data] Downloading package maxent_ne_chunker_tab to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker_tab is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\matth\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\words.zip.
# ORGANIZATION: USS Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS Enterprise
# PERSON      : United Federation
# ORGANIZATION: Planets Galaxy
# PERSON      : Starfleet
# ORGANIZATION: Enterprise
# ORGANIZATION: Federation
# ORGANIZATION: Battle
# GPE         : Veridian
# PERSON      : History Construction
# ORGANIZATION: Enterprise
# ORGANIZATION: Utopia Planitia Fleet
# PERSON      : Mars
# ORGANIZATION: Solar
# ORGANIZATION: Commander Orfil Quinteros
# PERSON      : Brahms
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# ORGANIZATION: USS Pegasus
# ORGANIZATION: Utopia Planitia
# PERSON      : Walter Pierce
# PERSON      : Marla Finn
# PERSON      : William Hodges
# PERSON      : Pierce
# ORGANIZATION: Enterprise
# PERSON      : Mars
# ORGANIZATION: Enterprise
# ORGANIZATION: Enterprise
# FACILITY    : Earth Station McKinley
# PERSON      : Captain Jean-Luc Picard
# ORGANIZATION: Rear Admiral Norah Satie
# PERSON      : Legacy Commander Riker
# ORGANIZATION: Enterprise
# PERSON      : Picard
# PERSON      : Deep Space
# GPE         : Starfleet
# PERSON      : Captain Benjamin Sisko
# ORGANIZATION: Enterprise
# GPE         : Worf
# ORGANIZATION: Enterprise
# PERSON      : Captain Picard
# ORGANIZATION: Class Sovereign
# ORGANIZATION: Enterprise
# PERSON      : Picard
# ORGANIZATION: CO
# GPE         : Worf
# ORGANIZATION: DS9

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# > > > > > > > > > © 2025 Institute of Data
#
#
# ---
#
#
#
# ---
